# %% [markdown]
# # interactive visualization of neurotranscriptome data

# %% [markdown]
# ### import python modules, initialize bokeh plots inline

# %%
from bokeh.io import output_notebook, output_server
from bokeh.plotting import figure,show

from bokeh.charts import *
import pandas as pd
import numpy as np


ANNOTATION = 'files/Additional file 3 - AaegLRU annotation.xlsx'
TPM_RU = 'files/Additional File 5 - TPM_all.xlsx'
TPM_VEC = 'files/Additional File 6 - TPM_all_AaegL3.3.xlsx'

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bb72ef72-d1d7-4233-bf4b-c4cf4a4af6e9">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### import TPM values and annotations

# %%
annotations = pd.read_excel(ANNOTATION)
tpm_ru = pd.read_excel(TPM_RU)
tpm_vec = pd.read_excel(TPM_VEC)

# %% [markdown]
# ### given a particular geneset, make a plot of brain TPM across gonotrophic cycle

# %%
genes = ['AAEL010779','AAEL000582']
gene_subset = tpm_ru.loc[tpm_ru['Vectorbase Identifier'].isin(genes)]
common_cols = ['Vectorbase Identifier','Internal gene ID','Display name','Gene family']

# %%
br_bf = ['Fe_Br_BF_1','Fe_Br_BF_2','Fe_Br_BF_3','Fe_Br_BF_4']
br_sf = ['Fe_Br_SF_1','Fe_Br_SF_4','Fe_Br_SF_5','Fe_Br_SF_6','Fe_Br_SF_7']
br_o = ['Fe_Br_O_1','Fe_Br_O_2','Fe_Br_O_3','Fe_Br_O_4']

brain_only = gene_subset[common_cols + br_sf + br_bf + br_o]
brain_only.melt = pd.melt(brain_only,id_vars = common_cols)
brain_only.melt.loc[brain_only.melt['variable'].isin(br_bf),'bloodfeeding state'] = 'bloodfed (48h)'
brain_only.melt.loc[brain_only.melt['variable'].isin(br_sf),'bloodfeeding state'] = 'sugarfed'
brain_only.melt.loc[brain_only.melt['variable'].isin(br_o),'bloodfeeding state'] = 'gravid (96h)'

# %%
brain_only.melt
# Out:
#    Vectorbase Identifier Internal gene ID Display name Gene family  \
# 0             AAEL000582        gene11525        ppk28         PPK
# 1             AAEL010779         gene9054        ppk16         PPK
# 2             AAEL000582        gene11525        ppk28         PPK
# 3             AAEL010779         gene9054        ppk16         PPK
# 4             AAEL000582        gene11525        ppk28         PPK
# 5             AAEL010779         gene9054        ppk16         PPK
# 6             AAEL000582        gene11525        ppk28         PPK
# 7             AAEL010779         gene9054        ppk16         PPK
# 8             AAEL000582        gene11525        ppk28         PPK
# 9             AAEL010779         gene9054        ppk16         PPK
# 10            AAEL000582        gene11525        ppk28         PPK
# 11            AAEL010779         gene9054        ppk16         PPK
# 12            AAEL000582        gene11525        ppk28         PPK
# 13            AAEL010779         gene9054        ppk16         PPK
# 14            AAEL000582        gene11525        ppk28         PPK
# 15            AAEL010779         gene9054        ppk16         PPK
# 16            AAEL000582        gene11525        ppk28         PPK
# 17            AAEL010779         gene9054        ppk16         PPK
# 18            AAEL000582        gene11525        ppk28         PPK
# 19            AAEL010779         gene9054        ppk16         PPK
# 20            AAEL000582        gene11525        ppk28         PPK
# 21            AAEL010779         gene9054        ppk16         PPK
# 22            AAEL000582        gene11525        ppk28         PPK
# 23            AAEL010779         gene9054        ppk16         PPK
# 24            AAEL000582        gene11525        ppk28         PPK
# 25            AAEL010779         gene9054        ppk16         PPK
#
#       variable     value bloodfeeding state
# 0   Fe_Br_SF_1  1.625860           sugarfed
# 1   Fe_Br_SF_1  1.198170           sugarfed
# 2   Fe_Br_SF_4  1.669528           sugarfed
# 3   Fe_Br_SF_4  0.789672           sugarfed
# 4   Fe_Br_SF_5  1.564817           sugarfed
# 5   Fe_Br_SF_5  0.676031           sugarfed
# 6   Fe_Br_SF_6  1.295775           sugarfed
# 7   Fe_Br_SF_6  0.557599           sugarfed
# 8   Fe_Br_SF_7  2.322594           sugarfed
# 9   Fe_Br_SF_7  0.446175           sugarfed
# 10  Fe_Br_BF_1  1.441909     bloodfed (48h)
# 11  Fe_Br_BF_1  0.467847     bloodfed (48h)
# 12  Fe_Br_BF_2  1.483530     bloodfed (48h)
# 13  Fe_Br_BF_2  0.623149     bloodfed (48h)
# 14  Fe_Br_BF_3  2.371607     bloodfed (48h)
# 15  Fe_Br_BF_3  0.843272     bloodfed (48h)
# 16  Fe_Br_BF_4  1.892280     bloodfed (48h)
# 17  Fe_Br_BF_4  0.630379     bloodfed (48h)
# 18   Fe_Br_O_1  1.608091       gravid (96h)
# 19   Fe_Br_O_1  0.590467       gravid (96h)
# 20   Fe_Br_O_2  1.507304       gravid (96h)
# 21   Fe_Br_O_2  0.359492       gravid (96h)
# 22   Fe_Br_O_3  1.816758       gravid (96h)
# 23   Fe_Br_O_3  0.729025       gravid (96h)
# 24   Fe_Br_O_4  1.961398       gravid (96h)
# 25   Fe_Br_O_4  0.849994       gravid (96h)

# %%
p_scatter = Scatter(brain_only.melt, x='Vectorbase Identifier', y='value',color='bloodfeeding state', xlabel="gene",ylabel="transcripts per million (TPM)")
p_box = Scatter(brain_only.melt, x='Vectorbase Identifier', y='value',color='bloodfeeding state', xlabel="gene",ylabel="transcripts per million (TPM)")

# %%
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="09eef42a-4c30-4163-ba6d-6c703f7b6492"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09eef42a-4c30-4163-ba6d-6c703f7b6492");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09eef42a-4c30-4163-ba6d-6c703f7b6492' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e210d2cd-3346-4fe3-b240-bc63595427c1":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2c19220e-0ac6-4641-958f-af982de68c0f","type":"Circle"},{"attributes":{"plot":null,"text":null},"id":"72397557-0e30-4d76-bf4d-c73137219b2b","type":"Title"},{"attributes":{},"id":"c696cc8f-7093-46b5-bf7c-ee460b669c32","type":"ToolEvents"},{"attributes":{"callback":null,"end":2.5728180186,"start":0.1582802514},"id":"05e36c55-0171-4926-9f6f-2d82b56b596c","type":"Range1d"},{"attributes":{"axis_label":"gene","formatter":{"id":"dbd6c59a-9ee8-4295-9d1e-f7ea0ac8ee3b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"07829638-194a-43e0-9010-b54b133f5845","subtype":"Chart","type":"Plot"},"ticker":{"id":"db445281-c4fe-4fdf-9704-5d09b3629960","type":"CategoricalTicker"}},"id":"65b452a0-f4f1-4e08-8c67-f2b443af0668","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"07829638-194a-43e0-9010-b54b133f5845","subtype":"Chart","type":"Plot"},"ticker":{"id":"db445281-c4fe-4fdf-9704-5d09b3629960","type":"CategoricalTicker"}},"id":"1d513dfa-d597-4069-ab7d-9ba23fc792e2","type":"Grid"},{"attributes":{"plot":{"id":"07829638-194a-43e0-9010-b54b133f5845","subtype":"Chart","type":"Plot"}},"id":"a2e1d926-7062-4fc2-ae23-e8ce031124a6","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"2ffcea7f-5968-4fd0-a488-56c50bf1e943","type":"Circle"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"bloodfeeding state":["gravid (96h)","gravid (96h)","gravid (96h)","gravid (96h)","gravid (96h)","gravid (96h)","gravid (96h)","gravid (96h)"],"chart_index":[{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"},{"bloodfeeding state":"gravid (96h)"}],"x_values":["AAEL000582","AAEL010779","AAEL000582","AAEL010779","AAEL000582","AAEL010779","AAEL000582","AAEL010779"],"y_values":[1.608090652,0.590467235,1.507304152,0.359491732,1.816758335,0.729025466,1.9613982,0.849993567]}},"id":"2f53c030-60c3-4470-87ec-21de95f929b2","type":"ColumnDataSource"},{"attributes":{},"id":"e0507535-c7b7-404b-afd1-c0c501a2d4b4","type":"BasicTicker"},{"attributes":{"plot":{"id":"07829638-194a-43e0-9010-b54b133f5845","subtype":"Chart","type":"Plot"}},"id":"4296419d-a7b4-4dde-a5b1-f992b8e0c16a","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"214c8b48-7785-40dc-a3bd-658219b1b03c","type":"Circle"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"bloodfeeding state":["sugarfed","sugarfed","sugarfed","sugarfed","sugarfed","sugarfed","sugarfed","sugarfed","sugarfed","sugarfed"],"chart_index":[{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"},{"bloodfeeding state":"sugarfed"}],"x_values":["AAEL000582","AAEL010779","AAEL000582","AAEL010779","AAEL000582","AAEL010779","AAEL000582","AAEL010779","AAEL000582","AAEL010779"],"y_values":[1.625860109,1.198170315,1.669527613,0.789671855,1.564816971,0.676031237,1.295775164,0.557598917,2.32259386,0.446175447]}},"id":"4ef6476e-3ead-4722-a6de-52714987da1e","type":"ColumnDataSource"},{"attri ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[30]</strong>&gt;</code></p>

# %% [markdown]
# ### very basic plot - everything hardcoded and output in notebook

# %%
tpm_plot = figure()

x = tpm_ru['Fe_An_BF_1']
y = tpm_ru['Fe_An_BF_2']

tpm_plot.scatter(x=np.log10(1+x),y=np.log10(1+y),fill_alpha=0.2)
show(tpm_plot)
# Out:
#     <div class="plotdiv" id="d6ee9d75-3644-4d63-97f3-34c221d4d8aa"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6ee9d75-3644-4d63-97f3-34c221d4d8aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6ee9d75-3644-4d63-97f3-34c221d4d8aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3f7953c8-2e22-4bdc-b9d2-53df8cda4bf1":{"roots":{"references":[{"attributes":{"plot":{"id":"f9580642-bf78-4ad7-bff1-fc9ef2a94bbc","subtype":"Figure","type":"Plot"}},"id":"88c2ac29-1181-4ab2-a434-c4e4352f7c7e","type":"HelpTool"},{"attributes":{},"id":"41ca13d1-5bcf-487e-9068-2c0882e571fa","type":"BasicTicker"},{"attributes":{"plot":{"id":"f9580642-bf78-4ad7-bff1-fc9ef2a94bbc","subtype":"Figure","type":"Plot"},"ticker":{"id":"41ca13d1-5bcf-487e-9068-2c0882e571fa","type":"BasicTicker"}},"id":"abec77fe-96e9-469b-aa57-3f0020d05a63","type":"Grid"},{"attributes":{"callback":null},"id":"d157c083-ec0b-4f22-9005-3c947f468bf7","type":"DataRange1d"},{"attributes":{},"id":"844c4d06-a6ce-4fd0-b457-976bedb47f01","type":"BasicTickFormatter"},{"attributes":{},"id":"e8a4cbf8-9651-4f55-bc6f-7caa5277e185","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"f9580642-bf78-4ad7-bff1-fc9ef2a94bbc","subtype":"Figure","type":"Plot"},"ticker":{"id":"e8a4cbf8-9651-4f55-bc6f-7caa5277e185","type":"BasicTicker"}},"id":"2ee5293d-29ed-4d29-9189-a5908d37ef81","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"371c0521-6071-4871-b486-cb5c2a2ae9ff","type":"Circle"},{"attributes":{"below":[{"id":"027c210c-fb83-4508-a87e-d22eee7e71cd","type":"LinearAxis"}],"left":[{"id":"4411bb84-f2f7-4c89-8947-6b84b1f89049","type":"LinearAxis"}],"renderers":[{"id":"027c210c-fb83-4508-a87e-d22eee7e71cd","type":"LinearAxis"},{"id":"abec77fe-96e9